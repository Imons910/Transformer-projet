# %%
import numpy as np
import matplotlib.pyplot as plt
from PIL import Image
import os

# %%
import numpy as np
import matplotlib.pyplot as plt
from PIL import Image  # C'est cette ligne qui manquait !
import os
# Remplace ceci par le chemin vers tes fichiers si nécessaire
img_path = r"C:\Users\simon\Documents\5A\transformer\DATASET_DEVOIR\images\21-12-03-18-50-31_Zivid_acquisition_color.jpg"
npy_path = r"C:\Users\simon\Documents\5A\transformer\DATASET_DEVOIR\depth\21-12-03-18-50-31_Zivid_acquisition_rawDepth.npy"
def visualize_data(img_path, npy_path):
    # 1. Charger l'image
    image = Image.open(img_path)
    
    # 2. Charger le fichier numpy (Nuage de points XYZ)
    # Le fichier contient (H, W, 3) -> X, Y, Z
    point_cloud = np.load(npy_path)
    
    # 3. Extraire seulement la profondeur (Z), qui est le 3ème canal
    # Z correspond à la distance en mètres ou millimètres (à vérifier selon l'échelle)
    depth_map = point_cloud[:, :, 2]
    
    # 4. Gestion des valeurs manquantes (NaN)
    # Les caméras depth ont souvent des "trous" où elles ne voient rien.
    # On remplace les NaN par 0 pour la visualisation, mais on devra les ignorer lors de l'entraînement.
    depth_map_vis = np.nan_to_num(depth_map, nan=0.0)

    print(f"Image size: {image.size}")
    print(f"Depth shape: {depth_map.shape}")
    print(f"Depth Min: {np.nanmin(depth_map):.3f}, Max: {np.nanmax(depth_map):.3f}")

    # 5. Affichage
    plt.figure(figsize=(12, 5))
    
    plt.subplot(1, 2, 1)
    plt.title("Image RGB")
    plt.imshow(image)
    plt.axis('off')
    
    plt.subplot(1, 2, 2)
    plt.title("Carte de Profondeur (Z)")
    plt.imshow(depth_map_vis, cmap='inferno') # 'inferno' rend bien pour la profondeur
    plt.colorbar(label='Profondeur (Z)')
    plt.axis('off')
    
    plt.tight_layout()
    plt.show()

# Si tu exécutes ce script localement, décommente la ligne ci-dessous
visualize_data(img_path, npy_path)
# Out:
# ---------------------------------------------------------------------------
# FileNotFoundError                         Traceback (most recent call last)
# Cell In[4], line 47
#      44     plt.show()
#      46 # Si tu exécutes ce script localement, décommente la ligne ci-dessous
# ---> 47 visualize_data(img_path, npy_path)
#
# Cell In[4], line 10, in visualize_data(img_path, npy_path)
#       8 def visualize_data(img_path, npy_path):
#       9     # 1. Charger l'image
# ---> 10     image = Image.open(img_path)
#      12     # 2. Charger le fichier numpy (Nuage de points XYZ)
#      13     # Le fichier contient (H, W, 3) -> X, Y, Z
#      14     point_cloud = np.load(npy_path)
#
# File c:\Users\simon\AppData\Local\Programs\Python\Python311\Lib\site-packages\PIL\Image.py:3493, in open(fp, mode, formats)
#    3491 if is_path(fp):
#    3492     filename = os.fspath(fp)
# -> 3493     fp = builtins.open(filename, "rb")
#    3494     exclusive_fp = True
#    3495 else:
#
# ...
